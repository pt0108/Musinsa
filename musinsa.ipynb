# %% [markdown]
# # 기본 데이터 스크래핑

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.musinsa.com/ranking/best?period=month&age=ALL&mainCategory=002&subCategory=&leafCategory=&price=&golf=false&kids=false&newProduct=false&exclusive=false&discount=false&soldOut=false&page=1&viewType=small&priceMin=&priceMax="

user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36"

headers = {"User-Agent" : user_agent}
response = requests.get(url, headers)
response.raise_for_status()

soup = BeautifulSoup(response.text, 'lxml')

# %%
# 브랜드
brands = soup.select('form#goodsRankForm div.list-box.box div.article_info p.item_title a')

for i, brand in enumerate(brands) :
    i += 1
    print(i, brand.text)
# Out:
# 1 드로우핏
# 2 스파오
# 3 내셔널지오그래픽
# 4 토피
# 5 노스페이스
# 6 쿠어
# 7 라퍼지스토어
# 8 스파오
# 9 파르티멘토
# 10 스파오
# 11 라퍼지스토어
# 12 코드그라피
# 13 예일
# 14 도프제이슨
# 15 예일
# 16 알파 인더스트리
# 17 비슬로우
# 18 무신사 스탠다드
# 19 코드그라피
# 20 내셔널지오그래픽
# 21 무신사 스탠다드
# 22 라퍼지스토어
# 23 라퍼지스토어
# 24 커버낫
# 25 라퍼지스토어
# 26 라퍼지스토어
# 27 내셔널지오그래픽
# 28 노이어
# 29 디스커버리 익스페디션
# 30 도프제이슨
# 31 무신사 스탠다드
# 32 무신사 스탠다드
# 33 내셔널지오그래픽
# 34 쿠어
# 35 무신사 스탠다드
# 36 라퍼지스토어
# 37 커버낫
# 38 커버낫
# 39 무신사 스탠다드
# 40 쿠어
# 41 무신사 스탠다드
# 42 후아유
# 43 드로우핏
# 44 커버낫
# 45 쿠어
# 46 예일
# 47 후아유
# 48 노스페이스
# 49 커버낫
# 50 키뮤어
# 51 라퍼지스토어
# 52 도프제이슨
# 53 무신사 스탠다드
# 54 내셔널지오그래픽
# 55 제멋
# 56 내셔널지오그래픽
# 57 메종미네드
# 58 디스커버리 익스페디션
# 59 파르티멘토
# 60 코드그라피
# 61 코드그라피
# 62 드로우핏
# 63 노스페이스
# 64 게스
# 65 코드그라피
# 66 인사일런스
# 67 케이투
# 68 후아유
# 69 무신사 스탠다드
# 70 예일
# 71 키뮤어
# 72 커버낫
# 73 무신사 스탠다드
# 74 라퍼지스토어
# 75 커버낫
# 76 라퍼지스토어
# 77 후아유
# 78 프리즘웍스
# 79 무신사 스탠다드
# 80 엠엘비
# 81 비슬로우
# 82 인사일런스
# 83 캘빈클라인 진
# 84 스파오
# 85 토피
# 86 파르티멘토
# 87 쿠어
# 88 디스이즈네버댓
# 89 노스페이스
# 90 라퍼지 포 우먼

# %%
# 제품명
names = soup.select('form#goodsRankForm div.list-box.box div.article_info p.list_info a')

for name in names :
    print(name['title'])
# Out:
# 프리미어 퓨어 캐시미어 히든 싱글 코트 [BLACK]
# 베이직 푸퍼_SPJPC4TC11
# N224MDW920 헤론 U넥 경량 다운 점퍼 CARBON BLACK
# 2WAY 스웻 후드 집업 (MELANGE GREY)
# NJ1DN75A 남성 1996 에코 눕시 자켓
# MTR 발마칸 코트 (블랙)
# [리뉴얼 ver.][3M 신슐레이트]오리지널 M-1965 피쉬테일 파카_Original Khaki
# 베이직 퍼플리스 집업_SPFZC4TU01
# [22F/W 리뉴얼] 오버사이즈 멜톤 더플 롱 코트 네이비
# 파스텔 푸퍼_SPJPC4TG01
# 버핑레더 오버핏 블루종_Black
# [내피분리형] US-ARMY 밀리터리 피쉬테일 후드 롱파카_카키
# REVERSIBLE WARM UP QUILTING JACKET BLACK / IVORY
# 오버핏 비건레더 싱글 자켓
# (22FW) WARM+ UP QUILTING JACKET BLACK
# MA-1 레귤러 Black
# 22FW OVERSIZED CASHMERE BALMACAAN COAT BLACK
# 캐시미어 블렌드 오버사이즈 싱글 코트 [블랙]
# [DIVO] RDS 유틸리티 덕다운 푸파 숏패딩_블랙
# N224MFJ910 남성 코스토니 플리스 뽀글이 후드 풀집업 SUGAR SWIZZLE IVORY
# 캐시미어 블렌드 오버사이즈 발마칸 코트 [블랙]
# [리뉴얼 ver.][3M 신슐레이트] M-1965 피쉬테일 숏 파카_Vintage Black
# 울리치 발마칸 오버 코트_Black
# 리버시블 쉐르파 집업 자켓 아이보리
# [무봉제]덕다운 심리스 미니멀 푸퍼 숏패딩_Black
# [리뉴얼 ver.][3M 신슐레이트]오리지널 M-1965 피쉬테일 파카_Vintage Black
# N224WDW920 여성 헤론 U넥 경량 덕다운 점퍼 L BEIGE
# 캐시미어 더블 브레스티드 코트 (블랙)
# 픽토르 U 구스다운 경량패딩 (BLACK)
# 솔리드 무톤 자켓
# 릴렉스드 베이식 블레이저 [블랙]
# 오버사이즈 MA-1 보머 재킷 [블랙]
# N224MFJ910 남성 코스토니 플리스 뽀글이 후드 풀집업 CARBON BLACK
# MTR 발마칸 코트 (멜란지토프)
# 우먼즈 캐시미어 블렌드 발마칸 로브 코트 [블랙]
# 덕다운 미니멀 블루종 패딩_Black
# 플리스 집업 자켓 블랙
# RDS 커버라이트 카라리스 다운 점퍼 블랙
# 다운 푸퍼 숏 패딩 재킷 [블랙]
# MTR 오버핏 더블 롱 코트 (블랙)
# 캐시미어 블렌드 대디 숄더 싱글 롱 코트 [블랙]
# 바시티 자켓 WHJJC4V24U
# 프리미어 퓨어 캐시미어 발마칸 코트 [BLACK]
# 리버시블 카라리스 쉐르파 집업 자켓 아이보리
# 퍼프 플라이트 MA-1 (블랙)
# (22FW) WARM+ UP QUILTING JACKET IVORY
# 리버서블 후드웜업 [3color] WHJJC4T01U
# NJ1DN50J 화이트라벨 노벨티 눕시 다운 자켓
# 숏 퀼팅 자켓 블랙
# 서플러스 울(WOOL) 65 세미오버 발마칸 코트_블랙
# [매트블랙] 버핑레더 미니멀 포켓 블루종_Matt Black
# 오버핏 램스킨 싱글 자켓
# 리버서블 플리스 숏 패딩 재킷 [블랙/크림]
# N224WDW920 여성 헤론 U넥 경량 덕 다운 점퍼 CARBON BLACK
# 리치 오버 MA-1 자켓 블랙 YHJK2269
# N224MDW920 헤론 U넥 경량 다운 점퍼 BEIGE
# BLACK DOUBLE LONG GOOSE DOWN
# 픽토르 U 구스다운 경량패딩 (IVORY)
# [비건 레더] 필드 자켓 블랙
# [DIVO] RDS 유틸리티 덕다운 푸파 숏패딩_쿨그레이
# 헤비 보아 플리스 무톤 자켓_블랙
# 프리미어 퓨어 캐시미어 로브 더블 코트 [BLACK]
# NC3NN50J 화이트라벨 알칸 EX 온볼 코트
# 남녀공용 베이직 푸퍼 다운_MM4W9891
# 헤비 보아 플리스 무톤 자켓_베이지
# 오버사이즈 발마칸 코트 BLACK
# 씬에어(THINAIR)ECO LITE_Black
# 리버서블 덤블 숏푸퍼 [5color] WHJPC4V02U
# 오버사이즈 디태처블 후드 MA-1 보머 재킷 [블랙]
# EMBROIDERY UNIVERSITY DAN FLEECE TRACK JACKET BLACK
# 서플러스 울(WOOL) 65 세미오버 더플 코트_네이비
# RDS 씨빅 다운 숏 푸퍼 블랙
# 베이식 블레이저 [블랙]
# 덕다운 아르틱 후드 패딩_Black
# 리버시블 쉐르파 후디 집업 자켓 아이보리
# [리뉴얼 ver.][3M 신슐레이트] M-1965 피쉬테일 숏 파카_Original Khaki
# 리버서블 후드웜업 [2color] WHJJC4T01U
# VINCENT M1965 FISHTAIL PARKA 004 _ OLIVE
# 오버사이즈 블레이저 [블랙]
# 베이직 스몰로고 숏패딩 NY (Black)
# 22FW OVERSIZED M65 HOOD SHORT DOWN PARKA BLACK
# MTR 캐시미어 발마칸 코트 BLACK
# 여 아이보리 숏 렝스 스탠드 카라 푸퍼 다운 재킷 J221163 ACF
# 리버서블 푸퍼_SPJDC4VC14
# 2WAY 스웻 후드 집업 (BLACK)
# 3M 신슐레이트 M-65 피시테일 코트 패딩 카키
# 오버사이즈 클래식 발마칸 코트 (멜란지차콜)
# PERTEX® T Down Jacket Black
# NJ4FN50J 화이트라벨 리모 플리스 자켓
# [Woman]울리치 트렌치 맥코트_Black

# %%
prices = soup.select('div.right_area.page-contents-best form#goodsRankForm div.list-box.box div.article_info p.price')
# for price in prices :
#     ori_price = price.select_one('del')
#     if ori_price : # del 태그가 있는 항목만
#         print("할인전 가격: ", ori_price.text)
#         print("할인후 가격: ", "잘안되네요")
#     else : # 할인이 없는 항목
#         print("할인없는 제품", price.text)
for price in prices :
    #print(price.text)
    prices = price.text.split()
    # print(prices)
    if len(prices) == 2:
        print("할인전 가격: ", prices[0])
        print("할인후 가격: ", prices[1])
    else:
        print("할인없는 제품", prices[0])
    print('*'*20)
# Out:
# 할인전 가격:  278,000원
# 할인후 가격:  219,000원
# ********************
# 할인없는 제품 69,900원
# ********************
# 할인없는 제품 149,000원
# ********************
# 할인전 가격:  45,000원
# 할인후 가격:  42,000원
# ********************
# 할인없는 제품 339,000원
# ********************
# 할인전 가격:  329,000원
# 할인후 가격:  296,100원
# ********************
# 할인전 가격:  138,000원
# 할인후 가격:  99,900원
# ********************
# 할인없는 제품 29,900원
# ********************
# 할인전 가격:  155,000원
# 할인후 가격:  124,000원
# ********************
# 할인없는 제품 69,900원
# ********************
# 할인전 가격:  94,000원
# 할인후 가격:  69,900원
# ********************
# 할인전 가격:  139,000원
# 할인후 가격:  98,900원
# ********************
# 할인전 가격:  129,000원
# 할인후 가격:  103,200원
# ********************
# 할인전 가격:  129,000원
# 할인후 가격:  89,000원
# ********************
# 할인전 가격:  99,000원
# 할인후 가격:  74,250원
# ********************
# 할인없는 제품 279,000원
# ********************
# 할인전 가격:  299,000원
# 할인후 가격:  254,150원
# ********************
# 할인없는 제품 159,900원
# ********************
# 할인전 가격:  124,000원
# 할인후 가격:  99,900원
# ********************
# 할인전 가격:  179,000원
# 할인후 가격:  159,000원
# ********************
# 할인없는 제품 199,900원
# ********************
# 할인전 가격:  129,000원
# 할인후 가격:  89,900원
# ********************
# 할인전 가격:  173,000원
# 할인후 가격:  118,000원
# ********************
# 할인전 가격:  129,000원
# 할인후 가격:  90,300원
# ********************
# 할인전 가격:  143,000원
# 할인후 가격:  89,900원
# ********************
# 할인전 가격:  138,000원
# 할인후 가격:  99,900원
# ********************
# 할인없는 제품 149,000원
# ********************
# 할인전 가격:  425,000원
# 할인후 가격:  297,000원
# ********************
# 할인없는 제품 159,000원
# ********************
# 할인전 가격:  186,000원
# 할인후 가격:  158,000원
# ********************
# 할인없는 제품 81,900원
# ********************
# 할인없는 제품 89,900원
# ********************
# 할인전 가격:  179,000원
# 할인후 가격:  159,000원
# ********************
# 할인전 가격:  329,000원
# 할인후 가격:  296,100원
# ********************
# 할인없는 제품 209,900원
# ********************
# 할인전 가격:  138,000원
# 할인후 가격:  99,800원
# ********************
# 할인전 가격:  79,000원
# 할인후 가격:  63,200원
# ********************
# 할인전 가격:  119,000원
# 할인후 가격:  95,200원
# ********************
# 할인없는 제품 119,900원
# ********************
# 할인전 가격:  334,000원
# 할인후 가격:  300,600원
# ********************
# 할인없는 제품 189,900원
# ********************
# 할인전 가격:  129,000원
# 할인후 가격:  116,100원
# ********************
# 할인전 가격:  308,000원
# 할인후 가격:  246,400원
# ********************
# 할인전 가격:  119,000원
# 할인후 가격:  83,300원
# ********************
# 할인전 가격:  235,000원
# 할인후 가격:  211,500원
# ********************
# 할인전 가격:  99,000원
# 할인후 가격:  74,250원
# ********************
# 할인전 가격:  99,900원
# 할인후 가격:  89,910원
# ********************
# 할인없는 제품 348,000원
# ********************
# 할인전 가격:  89,000원
# 할인후 가격:  71,200원
# ********************
# 할인전 가격:  209,000원
# 할인후 가격:  169,000원
# ********************
# 할인전 가격:  94,000원
# 할인후 가격:  69,900원
# ********************
# 할인전 가격:  339,000원
# 할인후 가격:  225,000원
# ********************
# 할인없는 제품 89,900원
# ********************
# 할인없는 제품 149,000원
# ********************
# 할인없는 제품 66,900원
# ********************
# 할인없는 제품 149,000원
# ********************
# 할인전 가격:  389,000원
# 할인후 가격:  299,000원
# ********************
# 할인없는 제품 159,000원
# ********************
# 할인전 가격:  111,700원
# 할인후 가격:  79,900원
# ********************
# 할인전 가격:  124,000원
# 할인후 가격:  99,900원
# ********************
# 할인전 가격:  109,000원
# 할인후 가격:  94,900원
# ********************
# 할인전 가격:  308,000원
# 할인후 가격:  246,400원
# ********************
# 할인없는 제품 258,000원
# ********************
# 할인전 가격:  108,000원
# 할인후 가격:  97,200원
# ********************
# 할인전 가격:  109,000원
# 할인후 가격:  94,900원
# ********************
# 할인전 가격:  377,000원
# 할인후 가격:  301,600원
# ********************
# 할인전 가격:  350,000원
# 할인후 가격:  252,000원
# ********************
# 할인전 가격:  129,000원
# 할인후 가격:  116,100원
# ********************
# 할인없는 제품 129,900원
# ********************
# 할인전 가격:  79,000원
# 할인후 가격:  59,250원
# ********************
# 할인전 가격:  209,000원
# 할인후 가격:  169,000원
# ********************
# 할인전 가격:  179,000원
# 할인후 가격:  125,300원
# ********************
# 할인전 가격:  79,900원
# 할인후 가격:  71,890원
# ********************
# 할인전 가격:  173,000원
# 할인후 가격:  138,000원
# ********************
# 할인전 가격:  149,000원
# 할인후 가격:  104,300원
# ********************
# 할인전 가격:  129,000원
# 할인후 가격:  89,900원
# ********************
# 할인전 가격:  99,900원
# 할인후 가격:  89,910원
# ********************
# 할인전 가격:  219,000원
# 할인후 가격:  186,150원
# ********************
# 할인전 가격:  83,900원
# 할인후 가격:  75,490원
# ********************
# 할인없는 제품 289,000원
# ********************
# 할인전 가격:  269,000원
# 할인후 가격:  228,650원
# ********************
# 할인전 가격:  422,000원
# 할인후 가격:  337,600원
# ********************
# 할인전 가격:  279,000원
# 할인후 가격:  251,100원
# ********************
# 할인전 가격:  89,900원
# 할인후 가격:  80,910원
# ********************
# 할인전 가격:  45,000원
# 할인후 가격:  42,000원
# ********************
# 할인전 가격:  155,000원
# 할인후 가격:  99,900원
# ********************
# 할인전 가격:  372,000원
# 할인후 가격:  334,800원
# ********************
# 할인전 가격:  219,000원
# 할인후 가격:  186,150원
# ********************
# 할인전 가격:  168,000원
# 할인후 가격:  159,600원
# ********************
# 할인전 가격:  163,000원
# 할인후 가격:  118,000원
# ********************

# %%
# 다 넣은 곳에서 쿠폰 있는거 없는거 찾기
all_items = soup.select('div.right_area.page-contents-best form#goodsRankForm div.list-box.box .li_box')
brands = soup.select('form#goodsRankForm div.list-box.box div.article_info p.item_title a')

for i, brand in zip(all_items, brands) :
    a = i.find('p', { 'class' : 'mu-icon mu-icon-coupon'})
    if a == None :
        print(brand.text, "쿠폰: x")
    else :
        print (brand.text, "쿠폰: o")
# Out:
# 드로우핏 쿠폰: x
# 스파오 쿠폰: o
# 내셔널지오그래픽 쿠폰: x
# 토피 쿠폰: x
# 노스페이스 쿠폰: x
# 쿠어 쿠폰: x
# 라퍼지스토어 쿠폰: o
# 스파오 쿠폰: o
# 파르티멘토 쿠폰: o
# 스파오 쿠폰: o
# 라퍼지스토어 쿠폰: o
# 코드그라피 쿠폰: x
# 예일 쿠폰: o
# 도프제이슨 쿠폰: x
# 예일 쿠폰: o
# 알파 인더스트리 쿠폰: x
# 비슬로우 쿠폰: x
# 무신사 스탠다드 쿠폰: x
# 코드그라피 쿠폰: x
# 내셔널지오그래픽 쿠폰: x
# 무신사 스탠다드 쿠폰: x
# 라퍼지스토어 쿠폰: o
# 라퍼지스토어 쿠폰: o
# 커버낫 쿠폰: x
# 라퍼지스토어 쿠폰: o
# 라퍼지스토어 쿠폰: o
# 내셔널지오그래픽 쿠폰: x
# 노이어 쿠폰: x
# 디스커버리 익스페디션 쿠폰: x
# 도프제이슨 쿠폰: x
# 무신사 스탠다드 쿠폰: x
# 무신사 스탠다드 쿠폰: x
# 내셔널지오그래픽 쿠폰: x
# 쿠어 쿠폰: x
# 무신사 스탠다드 쿠폰: x
# 라퍼지스토어 쿠폰: o
# 커버낫 쿠폰: x
# 커버낫 쿠폰: x
# 무신사 스탠다드 쿠폰: o
# 쿠어 쿠폰: x
# 무신사 스탠다드 쿠폰: x
# 후아유 쿠폰: x
# 드로우핏 쿠폰: x
# 커버낫 쿠폰: x
# 쿠어 쿠폰: x
# 예일 쿠폰: o
# 후아유 쿠폰: x
# 노스페이스 쿠폰: x
# 커버낫 쿠폰: x
# 키뮤어 쿠폰: x
# 라퍼지스토어 쿠폰: o
# 도프제이슨 쿠폰: x
# 무신사 스탠다드 쿠폰: o
# 내셔널지오그래픽 쿠폰: x
# 제멋 쿠폰: x
# 내셔널지오그래픽 쿠폰: x
# 메종미네드 쿠폰: x
# 디스커버리 익스페디션 쿠폰: x
# 파르티멘토 쿠폰: o
# 코드그라피 쿠폰: o
# 코드그라피 쿠폰: o
# 드로우핏 쿠폰: x
# 노스페이스 쿠폰: x
# 게스 쿠폰: x
# 코드그라피 쿠폰: o
# 인사일런스 쿠폰: x
# 케이투 쿠폰: x
# 후아유 쿠폰: x
# 무신사 스탠다드 쿠폰: x
# 예일 쿠폰: o
# 키뮤어 쿠폰: x
# 커버낫 쿠폰: x
# 무신사 스탠다드 쿠폰: x
# 라퍼지스토어 쿠폰: o
# 커버낫 쿠폰: x
# 라퍼지스토어 쿠폰: o
# 후아유 쿠폰: x
# 프리즘웍스 쿠폰: x
# 무신사 스탠다드 쿠폰: x
# 엠엘비 쿠폰: x
# 비슬로우 쿠폰: x
# 인사일런스 쿠폰: x
# 캘빈클라인 진 쿠폰: x
# 스파오 쿠폰: o
# 토피 쿠폰: x
# 파르티멘토 쿠폰: o
# 쿠어 쿠폰: x
# 디스이즈네버댓 쿠폰: x
# 노스페이스 쿠폰: x
# 라퍼지 포 우먼 쿠폰: o

# %%
# 리뷰 수 
points = soup.select('div.right_area.page-contents-best form#goodsRankForm div.list-box.box div.article_info p.point span.count')

for point in points :
    print(point.text)
# Out:
# 4,749
# 11,419
# 657
# 52,489
# 222
# 2,657
# 17,285
# 7,932
# 3,901
# 5,562
# 5,898
# 660
# 520
# 12,257
# 952
# 9,639
# 378
# 19,046
# 3,062
# 189
# 1,131
# 4,317
# 8,217
# 5,822
# 9,067
# 5,044
# 443
# 38
# 357
# 6,946
# 27,405
# 4,593
# 197
# 2,174
# 339
# 235
# 11,558
# 2,498
# 6,458
# 6,554
# 1,952
# 1,621
# 1,092
# 1,892
# 457
# 609
# 519
# 513
# 3,417
# 624
# 12,533
# 7,292
# 186
# 261
# 10,443
# 275
# 1,828
# 200
# 12,344
# 6,071
# 120
# 1,505
# 77
# 351
# 488
# 80
# 1,247
# 289
# 838
# 379
# 181
# 1,594
# 46,157
# 36
# 7,521
# 1,568
# 508
# 147
# 24,328
# 54
# 950
# 101
# 81
# 7,888
# 8,954
# 10,555
# 160
# 47
# 134
# 5,944

# %%
ii = 0
while ii < 90 :
    # 브랜드
    brands = soup.select('form#goodsRankForm div.list-box.box div.article_info p.item_title a')
    brd = "'"+brands[ii].text+"'"
    # 제품명
    names = soup.select('form#goodsRankForm div.list-box.box div.article_info p.list_info a')
    nm = "'"+(names[ii]['title'])+"'"
    # 다 넣은 곳에서 쿠폰 있는거 없는거 찾기
    all_items = soup.select('div.right_area.page-contents-best form#goodsRankForm div.list-box.box .li_box')
    a = all_items[ii].find('p', { 'class' : 'mu-icon mu-icon-coupon'})
    if a == None :
            coup =  "'x'"
    else :
            coup =  "'o'"
    # 리뷰 수
    points = soup.select('div.right_area.page-contents-best form#goodsRankForm div.list-box.box div.article_info p.point span.count')
    pp = points[ii].text.replace(',','')
    # 가격대
    prices = soup.select('div.right_area.page-contents-best form#goodsRankForm div.list-box.box div.article_info p.price')
    price11 = prices[ii].text.split()
    if len(price11) == 2:
        pri1 = price11[0][0:-1].replace(',','')
        pri2 = price11[1][0:-1].replace(',','')
    else:
        pri1 = price11[0][0:-1].replace(',','')
        pri2 = 0
    print('INSERT INTO musinsa VALUES (',ii+1, ',', brd, ',', nm, ',', pri1, ',', pri2, ',', pp , ',', coup ,');')
    ii += 1
# Out:
# INSERT INTO musinsa VALUES ( 1 , '드로우핏' , '프리미어 퓨어 캐시미어 히든 싱글 코트 [BLACK]' , 278000 , 219000 , 4749 , 'x' );
# INSERT INTO musinsa VALUES ( 2 , '스파오' , '베이직 푸퍼_SPJPC4TC11' , 69900 , 0 , 11419 , 'o' );
# INSERT INTO musinsa VALUES ( 3 , '내셔널지오그래픽' , 'N224MDW920 헤론 U넥 경량 다운 점퍼 CARBON BLACK' , 149000 , 0 , 657 , 'x' );
# INSERT INTO musinsa VALUES ( 4 , '토피' , '2WAY 스웻 후드 집업 (MELANGE GREY)' , 45000 , 42000 , 52489 , 'x' );
# INSERT INTO musinsa VALUES ( 5 , '노스페이스' , 'NJ1DN75A 남성 1996 에코 눕시 자켓' , 339000 , 0 , 222 , 'x' );
# INSERT INTO musinsa VALUES ( 6 , '쿠어' , 'MTR 발마칸 코트 (블랙)' , 329000 , 296100 , 2657 , 'x' );
# INSERT INTO musinsa VALUES ( 7 , '라퍼지스토어' , '[리뉴얼 ver.][3M 신슐레이트]오리지널 M-1965 피쉬테일 파카_Original Khaki' , 138000 , 99900 , 17285 , 'o' );
# INSERT INTO musinsa VALUES ( 8 , '스파오' , '베이직 퍼플리스 집업_SPFZC4TU01' , 29900 , 0 , 7932 , 'o' );
# INSERT INTO musinsa VALUES ( 9 , '파르티멘토' , '[22F/W 리뉴얼] 오버사이즈 멜톤 더플 롱 코트 네이비' , 155000 , 124000 , 3901 , 'o' );
# INSERT INTO musinsa VALUES ( 10 , '스파오' , '파스텔 푸퍼_SPJPC4TG01' , 69900 , 0 , 5562 , 'o' );
# INSERT INTO musinsa VALUES ( 11 , '라퍼지스토어' , '버핑레더 오버핏 블루종_Black' , 94000 , 69900 , 5898 , 'o' );
# INSERT INTO musinsa VALUES ( 12 , '코드그라피' , '[내피분리형] US-ARMY 밀리터리 피쉬테일 후드 롱파카_카키' , 139000 , 98900 , 660 , 'x' );
# INSERT INTO musinsa VALUES ( 13 , '예일' , 'REVERSIBLE WARM UP QUILTING JACKET BLACK / IVORY' , 129000 , 103200 , 520 , 'o' );
# INSERT INTO musinsa VALUES ( 14 , '도프제이슨' , '오버핏 비건레더 싱글 자켓' , 129000 , 89000 , 12257 , 'x' );
# INSERT INTO musinsa VALUES ( 15 , '예일' , '(22FW) WARM+ UP QUILTING JACKET BLACK' , 99000 , 74250 , 952 , 'o' );
# INSERT INTO musinsa VALUES ( 16 , '알파 인더스트리' , 'MA-1 레귤러 Black' , 279000 , 0 , 9639 , 'x' );
# INSERT INTO musinsa VALUES ( 17 , '비슬로우' , '22FW OVERSIZED CASHMERE BALMACAAN COAT BLACK' , 299000 , 254150 , 378 , 'x' );
# INSERT INTO musinsa VALUES ( 18 , '무신사 스탠다드' , '캐시미어 블렌드 오버사이즈 싱글 코트 [블랙]' , 159900 , 0 , 19046 , 'x' );
# INSERT INTO musinsa VALUES ( 19 , '코드그라피' , '[DIVO] RDS 유틸리티 덕다운 푸파 숏패딩_블랙' , 124000 , 99900 , 3062 , 'x' );
# INSERT INTO musinsa VALUES ( 20 , '내셔널지오그래픽' , 'N224MFJ910 남성 코스토니 플리스 뽀글이 후드 풀집업 SUGAR SWIZZLE IVORY' , 179000 , 159000 , 189 , 'x' );
# INSERT INTO musinsa VALUES ( 21 , '무신사 스탠다드' , '캐시미어 블렌드 오버사이즈 발마칸 코트 [블랙]' , 199900 , 0 , 1131 , 'x' );
# INSERT INTO musinsa VALUES ( 22 , '라퍼지스토어' , '[리뉴얼 ver.][3M 신슐레이트] M-1965 피쉬테일 숏 파카_Vintage Black' , 129000 , 89900 , 4317 , 'o' );
# INSERT INTO musinsa VALUES ( 23 , '라퍼지스토어' , '울리치 발마칸 오버 코트_Black' , 173000 , 118000 , 8217 , 'o' );
# INSERT INTO musinsa VALUES ( 24 , '커버낫' , '리버시블 쉐르파 집업 자켓 아이보리' , 129000 , 90300 , 5822 , 'x' );
# INSERT INTO musinsa VALUES ( 25 , '라퍼지스토어' , '[무봉제]덕다운 심리스 미니멀 푸퍼 숏패딩_Black' , 143000 , 89900 , 9067 , 'o' );
# INSERT INTO musinsa VALUES ( 26 , '라퍼지스토어' , '[리뉴얼 ver.][3M 신슐레이트]오리지널 M-1965 피쉬테일 파카_Vintage Black' , 138000 , 99900 , 5044 , 'o' );
# INSERT INTO musinsa VALUES ( 27 , '내셔널지오그래픽' , 'N224WDW920 여성 헤론 U넥 경량 덕다운 점퍼 L BEIGE' , 149000 , 0 , 443 , 'x' );
# INSERT INTO musinsa VALUES ( 28 , '노이어' , '캐시미어 더블 브레스티드 코트 (블랙)' , 425000 , 297000 , 38 , 'x' );
# INSERT INTO musinsa VALUES ( 29 , '디스커버리 익스페디션' , '픽토르 U 구스다운 경량패딩 (BLACK)' , 159000 , 0 , 357 , 'x' );
# INSERT INTO musinsa VALUES ( 30 , '도프제이슨' , '솔리드 무톤 자켓' , 186000 , 158000 , 6946 , 'x' );
# INSERT INTO musinsa VALUES ( 31 , '무신사 스탠다드' , '릴렉스드 베이식 블레이저 [블랙]' , 81900 , 0 , 27405 , 'x' );
# INSERT INTO musinsa VALUES ( 32 , '무신사 스탠다드' , '오버사이즈 MA-1 보머 재킷 [블랙]' , 89900 , 0 , 4593 , 'x' );
# INSERT INTO musinsa VALUES ( 33 , '내셔널지오그래픽' , 'N224MFJ910 남성 코스토니 플리스 뽀글이 후드 풀집업 CARBON BLACK' , 179000 , 159000 , 197 , 'x' );
# INSERT INTO musinsa VALUES ( 34 , '쿠어' , 'MTR 발마칸 코트 (멜란지토프)' , 329000 , 296100 , 2174 , 'x' );
# INSERT INTO musinsa VALUES ( 35 , '무신사 스탠다드' , '우먼즈 캐시미어 블렌드 발마칸 로브 코트 [블랙]' , 209900 , 0 , 339 , 'x' );
# INSERT INTO musinsa VALUES ( 36 , '라퍼지스토어' , '덕다운 미니멀 블루종 패딩_Black' , 138000 , 99800 , 235 , 'o' );
# INSERT INTO musinsa VALUES ( 37 , '커버낫' , '플리스 집업 자켓 블랙' , 79000 , 63200 , 11558 , 'x' );
# INSERT INTO musinsa VALUES ( 38 , '커버낫' , 'RDS 커버라이트 카라리스 다운 점퍼 블랙' , 119000 , 95200 , 2498 , 'x' );
# INSERT INTO musinsa VALUES ( 39 , '무신사 스탠다드' , '다운 푸퍼 숏 패딩 재킷 [블랙]' , 119900 , 0 , 6458 , 'o' );
# INSERT INTO musinsa VALUES ( 40 , '쿠어' , 'MTR 오버핏 더블 롱 코트 (블랙)' , 334000 , 300600 , 6554 , 'x' );
# INSERT INTO musinsa VALUES ( 41 , '무신사 스탠다드' , '캐시미어 블렌드 대디 숄더 싱글 롱 코트 [블랙]' , 189900 , 0 , 1952 , 'x' );
# INSERT INTO musinsa VALUES ( 42 , '후아유' , '바시티 자켓 WHJJC4V24U' , 129000 , 116100 , 1621 , 'x' );
# INSERT INTO musinsa VALUES ( 43 , '드로우핏' , '프리미어 퓨어 캐시미어 발마칸 코트 [BLACK]' , 308000 , 246400 , 1092 , 'x' );
# INSERT INTO musinsa VALUES ( 44 , '커버낫' , '리버시블 카라리스 쉐르파 집업 자켓 아이보리' , 119000 , 83300 , 1892 , 'x' );
# INSERT INTO musinsa VALUES ( 45 , '쿠어' , '퍼프 플라이트 MA-1 (블랙)' , 235000 , 211500 , 457 , 'x' );
# INSERT INTO musinsa VALUES ( 46 , '예일' , '(22FW) WARM+ UP QUILTING JACKET IVORY' , 99000 , 74250 , 609 , 'o' );
# INSERT INTO musinsa VALUES ( 47 , '후아유' , '리버서블 후드웜업 [3color] WHJJC4T01U' , 99900 , 89910 , 519 , 'x' );
# INSERT INTO musinsa VALUES ( 48 , '노스페이스' , 'NJ1DN50J 화이트라벨 노벨티 눕시 다운 자켓' , 348000 , 0 , 513 , 'x' );
# INSERT INTO musinsa VALUES ( 49 , '커버낫' , '숏 퀼팅 자켓 블랙' , 89000 , 71200 , 3417 , 'x' );
# INSERT INTO musinsa VALUES ( 50 , '키뮤어' , '서플러스 울(WOOL) 65 세미오버 발마칸 코트_블랙' , 209000 , 169000 , 624 , 'x' );
# INSERT INTO musinsa VALUES ( 51 , '라퍼지스토어' , '[매트블랙] 버핑레더 미니멀 포켓 블루종_Matt Black' , 94000 , 69900 , 12533 , 'o' );
# INSERT INTO musinsa VALUES ( 52 , '도프제이슨' , '오버핏 램스킨 싱글 자켓' , 339000 , 225000 , 7292 , 'x' );
# INSERT INTO musinsa VALUES ( 53 , '무신사 스탠다드' , '리버서블 플리스 숏 패딩 재킷 [블랙/크림]' , 89900 , 0 , 186 , 'o' );
# INSERT INTO musinsa VALUES ( 54 , '내셔널지오그래픽' , 'N224WDW920 여성 헤론 U넥 경량 덕 다운 점퍼 CARBON BLACK' , 149000 , 0 , 261 , 'x' );
# INSERT INTO musinsa VALUES ( 55 , '제멋' , '리치 오버 MA-1 자켓 블랙 YHJK2269' , 66900 , 0 , 10443 , 'x' );
# INSERT INTO musinsa VALUES ( 56 , '내셔널지오그래픽' , 'N224MDW920 헤론 U넥 경량 다운 점퍼 BEIGE' , 149000 , 0 , 275 , 'x' );
# INSERT INTO musinsa VALUES ( 57 , '메종미네드' , 'BLACK DOUBLE LONG GOOSE DOWN' , 389000 , 299000 , 1828 , 'x' );
# INSERT INTO musinsa VALUES ( 58 , '디스커버리 익스페디션' , '픽토르 U 구스다운 경량패딩 (IVORY)' , 159000 , 0 , 200 , 'x' );
# INSERT INTO musinsa VALUES ( 59 , '파르티멘토' , '[비건 레더] 필드 자켓 블랙' , 111700 , 79900 , 12344 , 'o' );
# INSERT INTO musinsa VALUES ( 60 , '코드그라피' , '[DIVO] RDS 유틸리티 덕다운 푸파 숏패딩_쿨그레이' , 124000 , 99900 , 6071 , 'o' );
# INSERT INTO musinsa VALUES ( 61 , '코드그라피' , '헤비 보아 플리스 무톤 자켓_블랙' , 109000 , 94900 , 120 , 'o' );
# INSERT INTO musinsa VALUES ( 62 , '드로우핏' , '프리미어 퓨어 캐시미어 로브 더블 코트 [BLACK]' , 308000 , 246400 , 1505 , 'x' );
# INSERT INTO musinsa VALUES ( 63 , '노스페이스' , 'NC3NN50J 화이트라벨 알칸 EX 온볼 코트' , 258000 , 0 , 77 , 'x' );
# INSERT INTO musinsa VALUES ( 64 , '게스' , '남녀공용 베이직 푸퍼 다운_MM4W9891' , 108000 , 97200 , 351 , 'x' );
# INSERT INTO musinsa VALUES ( 65 , '코드그라피' , '헤비 보아 플리스 무톤 자켓_베이지' , 109000 , 94900 , 488 , 'o' );
# INSERT INTO musinsa VALUES ( 66 , '인사일런스' , '오버사이즈 발마칸 코트 BLACK' , 377000 , 301600 , 80 , 'x' );
# INSERT INTO musinsa VALUES ( 67 , '케이투' , '씬에어(THINAIR)ECO LITE_Black' , 350000 , 252000 , 1247 , 'x' );
# INSERT INTO musinsa VALUES ( 68 , '후아유' , '리버서블 덤블 숏푸퍼 [5color] WHJPC4V02U' , 129000 , 116100 , 289 , 'x' );
# INSERT INTO musinsa VALUES ( 69 , '무신사 스탠다드' , '오버사이즈 디태처블 후드 MA-1 보머 재킷 [블랙]' , 129900 , 0 , 838 , 'x' );
# INSERT INTO musinsa VALUES ( 70 , '예일' , 'EMBROIDERY UNIVERSITY DAN FLEECE TRACK JACKET BLACK' , 79000 , 59250 , 379 , 'o' );
# INSERT INTO musinsa VALUES ( 71 , '키뮤어' , '서플러스 울(WOOL) 65 세미오버 더플 코트_네이비' , 209000 , 169000 , 181 , 'x' );
# INSERT INTO musinsa VALUES ( 72 , '커버낫' , 'RDS 씨빅 다운 숏 푸퍼 블랙' , 179000 , 125300 , 1594 , 'x' );
# INSERT INTO musinsa VALUES ( 73 , '무신사 스탠다드' , '베이식 블레이저 [블랙]' , 79900 , 71890 , 46157 , 'x' );
# INSERT INTO musinsa VALUES ( 74 , '라퍼지스토어' , '덕다운 아르틱 후드 패딩_Black' , 173000 , 138000 , 36 , 'o' );
# INSERT INTO musinsa VALUES ( 75 , '커버낫' , '리버시블 쉐르파 후디 집업 자켓 아이보리' , 149000 , 104300 , 7521 , 'x' );
# INSERT INTO musinsa VALUES ( 76 , '라퍼지스토어' , '[리뉴얼 ver.][3M 신슐레이트] M-1965 피쉬테일 숏 파카_Original Khaki' , 129000 , 89900 , 1568 , 'o' );
# INSERT INTO musinsa VALUES ( 77 , '후아유' , '리버서블 후드웜업 [2color] WHJJC4T01U' , 99900 , 89910 , 508 , 'x' );
# INSERT INTO musinsa VALUES ( 78 , '프리즘웍스' , 'VINCENT M1965 FISHTAIL PARKA 004 _ OLIVE' , 219000 , 186150 , 147 , 'x' );
# INSERT INTO musinsa VALUES ( 79 , '무신사 스탠다드' , '오버사이즈 블레이저 [블랙]' , 83900 , 75490 , 24328 , 'x' );
# INSERT INTO musinsa VALUES ( 80 , '엠엘비' , '베이직 스몰로고 숏패딩 NY (Black)' , 289000 , 0 , 54 , 'x' );
# INSERT INTO musinsa VALUES ( 81 , '비슬로우' , '22FW OVERSIZED M65 HOOD SHORT DOWN PARKA BLACK' , 269000 , 228650 , 950 , 'x' );
# INSERT INTO musinsa VALUES ( 82 , '인사일런스' , 'MTR 캐시미어 발마칸 코트 BLACK' , 422000 , 337600 , 101 , 'x' );
# INSERT INTO musinsa VALUES ( 83 , '캘빈클라인 진' , '여 아이보리 숏 렝스 스탠드 카라 푸퍼 다운 재킷 J221163 ACF' , 279000 , 251100 , 81 , 'x' );
# INSERT INTO musinsa VALUES ( 84 , '스파오' , '리버서블 푸퍼_SPJDC4VC14' , 89900 , 80910 , 7888 , 'o' );
# INSERT INTO musinsa VALUES ( 85 , '토피' , '2WAY 스웻 후드 집업 (BLACK)' , 45000 , 42000 , 8954 , 'x' );
# INSERT INTO musinsa VALUES ( 86 , '파르티멘토' , '3M 신슐레이트 M-65 피시테일 코트 패딩 카키' , 155000 , 99900 , 10555 , 'o' );
# INSERT INTO musinsa VALUES ( 87 , '쿠어' , '오버사이즈 클래식 발마칸 코트 (멜란지차콜)' , 372000 , 334800 , 160 , 'x' );
# INSERT INTO musinsa VALUES ( 88 , '디스이즈네버댓' , 'PERTEX® T Down Jacket Black' , 219000 , 186150 , 47 , 'x' );
# INSERT INTO musinsa VALUES ( 89 , '노스페이스' , 'NJ4FN50J 화이트라벨 리모 플리스 자켓' , 168000 , 159600 , 134 , 'x' );
# INSERT INTO musinsa VALUES ( 90 , '라퍼지 포 우먼' , '[Woman]울리치 트렌치 맥코트_Black' , 163000 , 118000 , 5944 , 'o' );
